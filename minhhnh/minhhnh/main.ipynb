# %%
from dataset import Dataset
from trainer import Trainer
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train, y_train, x_test, y_test = Dataset(
    "data/train_record.csv", "data/test_record.csv", scaler
).get([0, 4, 7, 11], -1)

# %%
Trainer().fit(x_train, y_train, x_test, y_test, n_splits=25)
# Out:
# 100%|██████████| 100/100 [02:04<00:00,  1.25s/it, best_test_acc=0.804, test_acc=0.51, train_acc=0.878, val_acc=0.8]
# Fold  0
# 100%|██████████| 100/100 [01:54<00:00,  1.15s/it, best_test_acc=0.863, test_acc=0.686, train_acc=0.937, val_acc=0.8]
# Fold  1
# 100%|██████████| 100/100 [01:53<00:00,  1.14s/it, best_test_acc=0.863, test_acc=0.725, train_acc=0.979, val_acc=0.7]
# Fold  2
# 100%|██████████| 100/100 [01:45<00:00,  1.05s/it, best_test_acc=0.863, test_acc=0.745, train_acc=0.979, val_acc=0.6]
# Fold  3
# 100%|██████████| 100/100 [01:47<00:00,  1.08s/it, best_test_acc=0.863, test_acc=0.627, train_acc=0.962, val_acc=1]
# Fold  4
# 100%|██████████| 100/100 [01:50<00:00,  1.10s/it, best_test_acc=0.882, test_acc=0.784, train_acc=0.878, val_acc=0.8]
# Fold  5
# 100%|██████████| 100/100 [01:47<00:00,  1.08s/it, best_test_acc=0.882, test_acc=0.647, train_acc=0.971, val_acc=1]
# Fold  6
# 100%|██████████| 100/100 [01:47<00:00,  1.08s/it, best_test_acc=0.882, test_acc=0.765, train_acc=0.962, val_acc=0.8]
# Fold  7
# 100%|██████████| 100/100 [01:45<00:00,  1.06s/it, best_test_acc=0.882, test_acc=0.549, train_acc=0.962, val_acc=0.9]
# Fold  8
# 100%|██████████| 100/100 [01:48<00:00,  1.08s/it, best_test_acc=0.882, test_acc=0.725, train_acc=0.983, val_acc=0.9]
# Fold  9
# 100%|██████████| 100/100 [01:47<00:00,  1.08s/it, best_test_acc=0.882, test_acc=0.824, train_acc=0.979, val_acc=0.8]
# Fold  10
# 100%|██████████| 100/100 [01:53<00:00,  1.13s/it, best_test_acc=0.882, test_acc=0.725, train_acc=0.966, val_acc=0.7]
# Fold  11
# 100%|██████████| 100/100 [01:52<00:00,  1.12s/it, best_test_acc=0.882, test_acc=0.627, train_acc=0.958, val_acc=0.8]
# Fold  12
# 100%|██████████| 100/100 [01:52<00:00,  1.13s/it, best_test_acc=0.882, test_acc=0.647, train_acc=0.929, val_acc=0.7]
# Fold  13
# 100%|██████████| 100/100 [01:51<00:00,  1.12s/it, best_test_acc=0.882, test_acc=0.627, train_acc=0.903, val_acc=0.8]
# Fold  14
# 100%|██████████| 100/100 [02:00<00:00,  1.21s/it, best_test_acc=0.882, test_acc=0.686, train_acc=0.966, val_acc=0.7]
# Fold  15
# 100%|██████████| 100/100 [02:05<00:00,  1.25s/it, best_test_acc=0.882, test_acc=0.667, train_acc=0.966, val_acc=0.8]
# Fold  16
# 100%|██████████| 100/100 [01:52<00:00,  1.13s/it, best_test_acc=0.882, test_acc=0.706, train_acc=0.971, val_acc=0.9]
# Fold  17
# 100%|██████████| 100/100 [01:49<00:00,  1.10s/it, best_test_acc=0.882, test_acc=0.667, train_acc=0.992, val_acc=0.5]
# Fold  18
# 100%|██████████| 100/100 [01:54<00:00,  1.14s/it, best_test_acc=0.882, test_acc=0.686, train_acc=0.962, val_acc=0.8]
# Fold  19
# 100%|██████████| 100/100 [01:56<00:00,  1.17s/it, best_test_acc=0.882, test_acc=0.745, train_acc=0.954, val_acc=0.9]
# Fold  20
# 100%|██████████| 100/100 [01:56<00:00,  1.16s/it, best_test_acc=0.882, test_acc=0.529, train_acc=0.958, val_acc=0.8]
# Fold  21
# 100%|██████████| 100/100 [01:56<00:00,  1.17s/it, best_test_acc=0.882, test_acc=0.725, train_acc=0.979, val_acc=0.9]
# Fold  22
# 100%|██████████| 100/100 [01:54<00:00,  1.14s/it, best_test_acc=0.882, test_acc=0.686, train_acc=0.962, val_acc=0.556]
# Fold  23
# 100%|██████████| 100/100 [01:58<00:00,  1.18s/it, best_test_acc=0.882, test_acc=0.765, train_acc=0.971, val_acc=1]
# Fold  24
